# %% [markdown]
# ## Feature Scaling
# - Method to scale numeric features in the same scale or range
# - Last step in data preprocessing.
# - aka data normalization.
# - We apply FS on independent variables.

# %% [markdown]
# - If height is 140 cm and 8.2 feet. Here, we use FS.

# %% [markdown]
# - KNN, K MEANS, SVM , PCA -> We have to scale features as for calculating distances and vectors.

# %% [markdown]
# - Tree based algo like decision tree, random forest etc doesnt need fs.

# %% [markdown]
# #### STANDARDIZATION :
# - RESCALE THE FEATURE SUCH AS MEAN=0 AND SD=1.
# - Z-SCORE = ```(X - MEAN ) / SD```
# - IF DATA FOLLOW `NORMAL DISTRIBUTION` THEN WE CAN APPLY THIS BUT SHAPE WILL REMAIN INTACT.

# %% [markdown]
# #### NORMALISATION
# - WE SCALE THE FEATURE IN FIXED RANGE BETWEEN 0 - 1.
# - X_NORM = `X - X_MIN / X_MAX - X_MIN`
# - AKA `MIN-MAX SCALING` .

# %% [markdown]
# THERE IS NO THUMB RULE TO USE STANDARDISATION OR NORMALISATION FOR SPECIAL ML ALGO.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_main = df[['survived','pclass','age','parch']]
df_main.head()
# Out:
#    survived  pclass   age  parch
# 0         0       3  22.0      0
# 1         1       1  38.0      0
# 2         1       3  26.0      0
# 3         1       1  35.0      0
# 4         0       3  35.0      0

# %%
# to get rid of nan values 
df3 = df_main.fillna(df_main.mean())
df3.head()
# Out:
#    survived  pclass   age  parch
# 0         0       3  22.0      0
# 1         1       1  38.0      0
# 2         1       3  26.0      0
# 3         1       1  35.0      0
# 4         0       3  35.0      0

# %%
X = df3.drop("survived", axis=1)
Y = df3["survived"]
X.shape, Y.shape
# Out:
# ((891, 3), (891,))

# %%
x_train, x_test, y_train, y_test =  train_test_split(X, Y, test_size=0.2, random_state=51)

# %%
# x_train.head() 
# y_train.tail()

# %%
sc = StandardScaler()
sc.fit(x_train)
sc.mean_ 
sc.scale_
# Out:
# array([ 0.84405789, 12.99162985,  0.79647463])

# %%
x_train_sc = sc.transform(x_train)
x_test_sc = sc.transform(x_test)
# Out:
# c:\Users\91993\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\91993\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
x_train_sc = pd.DataFrame(x_train_sc, columns=["pclass","age","parch"])
x_test_sc = pd.DataFrame(x_test_sc, columns=["pclass","age","parch"])

# %%
mmc = MinMaxScaler()
mmc.fit(x_train)
# Out:
# MinMaxScaler()
